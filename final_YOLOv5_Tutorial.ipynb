# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %%
"ganesha"
# Out:
# 'ganesha'

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅

# %%
# to unzip the dataset folder we uploaded

# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %%
# change epochs for accuracy

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 85 --data coco128.yaml --weights yolov5s.pt --cache

#to check the accuracy see  mAP@.5
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=85, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# replace our model trained weights with the above default weights (yolov5s.pt)
#also change 'data/images' with your own video
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.45 --source ../dogs_video.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=../dogs_video.mp4, imgsz=[640, 640], conf_thres=0.45, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-89-g540ef0d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/602) /content/dogs_video.mp4: 384x640 1 dog, Done. (0.029s)
# video 1/1 (2/602) /content/dogs_video.mp4: 384x640 1 dog, Done. (0.027s)
# video 1/1 (3/602) /content/dogs_video.mp4: 384x640 1 dog, Done. (0.027s)
# video 1/1 (4/602) /content/dogs_video.mp4: 384x640 1 dog, Done. (0.027s)
# video 1/1 (5/602) /content/dogs_video.mp4: 384x640 1 dog, Done. (0.027s)
# ...
